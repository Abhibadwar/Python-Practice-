# %%
# how do you convert string to an integer in py
n = "10"
num = int(n)
num
# Out:
# 10

# %%
# How do you check data type of variable 
n = 10
print(type(n))
# Out:
# <class 'int'>

# %%
# how do you concatenate two string 
s1 = "hello"
s2 = "Abhishek"

r = s1 + s2
r
# Out:
# 'helloAbhishek'

# %%
# How do you find the length 
s = "Abhishek"
l = len(s)
l
# Out:
# 8

# %%
# how do you upper case in py
s ="abhishek"
u = s.upper()
u
# Out:
# 'ABHISHEK'

# %%
# split string a substring
s = "Abhishek, Baadwar"
sub = s.split(",")
sub
# Out:
# ['Abhishek', ' Baadwar']

# %%
# check if a string contains a specific substring 
s = "Hello Abhishek"
p = "Abhishek" in s
p
# Out:
# True

# %%
# How do you write if else 
if condition:
    True
else:
    False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # How do you write if else
# ----> 2 if condition:
#       3     True
#       4 else:
#
# NameError: name 'condition' is not defined

# %%
# square 
s = lambda x: x**2
s(3)
# Out:
# 9

# %%
n = [2,3,4,5,6,7,8]
s = [i**2 for i in n ]
s
# Out:
# [4, 9, 16, 25, 36, 49, 64]

# %%
# filter element in list using list comprehension
n = [2,3,4,5,6,7,8]
even = [x for x in n if x % 2==0]
even
# Out:
# [2, 4, 6, 8]

# %%
n = [2,3,4,5,6,7,8]
odd = [x for x in n if x % 3==0]
odd
# Out:
# [3, 6]
